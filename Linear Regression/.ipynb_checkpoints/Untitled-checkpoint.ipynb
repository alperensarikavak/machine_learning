# %%
# !pip install numpy==2.2.0
# !pip install pandas==2.2.3
# !pip install scikit-learn==1.6.0
# !pip install matplotlib==3.9.3
# Out:
# ...
#      ---------------------------------------- 0.0/12.9 MB ? eta -:--:--
#      ---------------------------------------- 0.0/12.9 MB 1.4 MB/s eta 0:00:10
#      ---------------------------------------- 0.1/12.9 MB 1.3 MB/s eta 0:00:10
#       --------------------------------------- 0.2/12.9 MB 2.0 MB/s eta 0:00:07
#      - -------------------------------------- 0.5/12.9 MB 2.8 MB/s eta 0:00:05
#      -- ------------------------------------- 0.9/12.9 MB 4.1 MB/s eta 0:00:03
#      -- ------------------------------------- 0.9/12.9 MB 4.1 MB/s eta 0:00:03
#      -- ------------------------------------- 0.9/12.9 MB 4.1 MB/s eta 0:00:03
#      -- ------------------------------------- 0.9/12.9 MB 4.1 MB/s eta 0:00:03
#      -- ------------------------------------- 0.9/12.9 MB 4.1 MB/s eta 0:00:03
#      -- ------------------------------------- 0.9/12.9 MB 4.1 MB/s eta 0:00:03
#      -- ------------------------------------- 0.9/12.9 MB 4.1 MB/s eta 0:00:03
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
# %matplotlib inline

# %%
import pandas as pd


df = pd.read_csv("Walmart_Sales.csv")


df.sample(5)
# Out:
#       Store        Date  Weekly_Sales  Holiday_Flag  Temperature  Fuel_Price  \
# 3435     25  26-02-2010     628516.57             0        29.16       2.754
# 5459     39  30-07-2010    1308222.24             0        80.99       2.640
# 4940     35  05-08-2011     826820.71             0        78.14       3.842
# 4398     31  02-03-2012    1427881.22             0        59.30       3.630
# 3098     22  02-12-2011    1167621.14             0        49.11       3.501
#
#              CPI  Unemployment
# 3435  204.463087         8.187
# 5459  210.128679         8.360
# 4940  139.989649         8.684
# 4398  220.486689         7.057
# 3098  140.430786         7.706

# %%
df.describe()
# Out:
#              Store  Weekly_Sales  Holiday_Flag  Temperature   Fuel_Price  \
# count  6435.000000  6.435000e+03   6435.000000  6435.000000  6435.000000
# mean     23.000000  1.046965e+06      0.069930    60.663782     3.358607
# std      12.988182  5.643666e+05      0.255049    18.444933     0.459020
# min       1.000000  2.099862e+05      0.000000    -2.060000     2.472000
# 25%      12.000000  5.533501e+05      0.000000    47.460000     2.933000
# 50%      23.000000  9.607460e+05      0.000000    62.670000     3.445000
# 75%      34.000000  1.420159e+06      0.000000    74.940000     3.735000
# max      45.000000  3.818686e+06      1.000000   100.140000     4.468000
#
#                CPI  Unemployment
# count  6435.000000   6435.000000
# mean    171.578394      7.999151
# std      39.356712      1.875885
# min     126.064000      3.879000
# 25%     131.735000      6.891000
# 50%     182.616521      7.874000
# 75%     212.743293      8.622000
# max     227.232807     14.313000

# %%
cdf = df[['Store','Weekly_Sales','Holiday_Flag','Temperature','CPI','Fuel_Price','Unemployment']]
cdf.sample(9)
# Out:
#       Store  Weekly_Sales  Holiday_Flag  Temperature         CPI  Fuel_Price  \
# 5844     41    1386407.17             0        66.88  197.738934       3.735
# 3211     23    1359921.13             0        50.07  134.514367       4.078
# 5259     37     520887.23             0        69.18  219.970560       3.787
# 2765     20    1843030.95             0        31.43  204.648780       3.193
# 626       5     356622.61             0        58.83  213.806830       3.045
# 6392     45     714081.05             0        35.88  189.194056       3.422
# 3529     25     997502.47             0        33.09  212.068504       3.413
# 2300     17     807798.73             0        43.82  126.380567       2.941
# 759       6    1834737.58             0        48.46  212.980406       2.843
#
#       Unemployment
# 5844         6.547
# 3211         4.781
# 5259         7.244
# 2765         7.343
# 626          6.634
# 6392         8.424
# 3529         7.082
# 2300         6.635
# ...

# %%
viz = cdf[['Store','Weekly_Sales','Holiday_Flag','Temperature','CPI','Fuel_Price','Unemployment']]
viz.hist()
plt.show()

# %%
plt.scatter(cdf.Temperature, cdf.Fuel_Price,  color='blue')
plt.xlabel("Engine size")
plt.ylabel("Emission")
plt.xlim(0,7)
plt.show()
